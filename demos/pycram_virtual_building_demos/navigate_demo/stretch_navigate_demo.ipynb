# %%
from setup_demo_manager import start_demo
from stretch_navigate_demo import navigate_demo
from setup_launch_robot import launch_stretch

launch_stretch()
start_demo(navigate_demo)
# Out:
# ... logging to /home/vee/.ros/log/d9513908-6ad8-11ef-9091-61e8751eef35/roslaunch-venevo-25185.log
# started roslaunch server http://venevo:39839/
#
# SUMMARY
# ========
#
# PARAMETERS
#  * /robot_description: <?xml version="1....
#  * /rosdistro: noetic
#  * /rosversion: 1.16.0
#
# NODES
#   /
#     kdl_ik_service (kdl_ik_service/start_ros_server.py)
#
# ROS_MASTER_URI=http://localhost:11311
# process[kdl_ik_service-2]: started with pid [26773]
# [INFO] [1725467554.755787]: ik_and_description.launch started
# IK server ready.
# shutdown request: [/kdl_ik_service] Reason: new node registered with same name
# [kdl_ik_service-1] process has finished cleanly
# log file: /home/vee/.ros/log/d9513908-6ad8-11ef-9091-61e8751eef35/kdl_ik_service-1*.log
# all processes on machine have died, roslaunch will exit
# HBox(children=(HTML(value='<img src="...…
# Found file stretch_description.urdf in /home/vee/robocup_workspaces/pycram_ws/src/pycram/src/pycram/datastructures/../../../resources/robots/stretch_description.urdf
# [ERROR] [1725467557.224918]: Could not find resource package linked in this URDF
# ---------------------------------------------------------------------------
# ResourceNotFound                          Traceback (most recent call last)
# Cell In[2], line 6
#       3 from setup_launch_robot import launch_stretch
#       5 launch_stretch()
# ----> 6 start_demo(navigate_demo)
#
# File ~/robocup_workspaces/pycram_ws/src/pycram/demos/pycram_virtual_building_demos/setup_demo_manager.py:10, in start_demo(func)
#       8 output = Output()
#       9 text_widget = display_loading_gif_with_text()
# ---> 10 func()
#      11 update_text(text_widget, 'Almost done...')
#
# File ~/robocup_workspaces/pycram_ws/src/pycram/demos/pycram_virtual_building_demos/stretch_navigate_demo.py:34, in navigate_demo()
#      33 def navigate_demo():
# ---> 34     navigate_main()
#
# File ~/robocup_workspaces/pycram_ws/src/pycram/demos/pycram_virtual_building_demos/stretch_navigate_demo.py:17, in navigate_main()
#      15 world = BulletWorld(WorldMode.DIRECT)
#      16 viz_marker = VizMarkerPublisher()
# ---> 17 robot = Object("stretch", ObjectType.ROBOT, f"stretch_description{extension}", pose=Pose([1, 2, 0]))
#      18 apartment = Object("apartment", ObjectType.ENVIRONMENT, f"apartment{extension}")
#      20 robot_desig = BelieveObject(names=["stretch"])
#
# File ~/robocup_workspaces/pycram_ws/src/pycram/src/pycram/world_concepts/world_object.py:77, in Object.__init__(self, name, obj_type, path, description, pose, world, color, ignore_cached_files)
#      74 self.original_pose = self.local_transformer.transform_pose(pose, "map")
#      75 self._current_pose = self.original_pose
# ---> 77 self.id, self.path = self._load_object_and_get_id(path, ignore_cached_files)
#      79 self.description.update_description_from_file(self.path)
#      81 self.tf_frame = ((self.prospection_world_prefix if self.world.is_prospection_world else "")
#      82                  + f"{self.name}")
#
# File ~/robocup_workspaces/pycram_ws/src/pycram/src/pycram/world_concepts/world_object.py:130, in Object._load_object_and_get_id(self, path, ignore_cached_files)
#     128 if path is not None:
#     129     try:
# --> 130         path = self.world.update_cache_dir_with_object(path, ignore_cached_files, self)
#     131     except FileNotFoundError as e:
#     132         logging.error("Could not generate description from file.")
#
# File ~/robocup_workspaces/pycram_ws/src/pycram/src/pycram/datastructures/world.py:246, in World.update_cache_dir_with_object(self, path, ignore_cached_files, obj)
#     237 def update_cache_dir_with_object(self, path: str, ignore_cached_files: bool,
#     238                                  obj: Object) -> str:
#     239     """
#     240     Updates the cache directory with the given object.
#     241
#    (...)
#     244     :param obj: The object to be added to the cache directory.
#     245     """
# --> 246     return self.cache_manager.update_cache_dir_with_object(path, ignore_cached_files, obj.description, obj.name)
#
# File ~/robocup_workspaces/pycram_ws/src/pycram/src/pycram/cache_manager.py:54, in CacheManager.update_cache_dir_with_object(self, path, ignore_cached_files, object_description, object_name)
#      51 if not self.is_cached(path, object_description) or ignore_cached_files:
#      52     # if file is not yet cached preprocess the description file and save it in the cache directory.
#      53     path = self.look_for_file_in_data_dir(path_object)
# ---> 54     self.generate_description_and_write_to_cache(path, object_name, extension, cache_path, object_description)
#      56 return cache_path
#
# File ~/robocup_workspaces/pycram_ws/src/pycram/src/pycram/cache_manager.py:69, in CacheManager.generate_description_and_write_to_cache(self, path, name, extension, cache_path, object_description)
#      58 def generate_description_and_write_to_cache(self, path: str, name: str, extension: str, cache_path: str,
#      59                                             object_description: 'ObjectDescription') -> None:
#      60     """
#      61     Generates the description from the file at the given path and writes it to the cache directory.
#      62
#    (...)
#      67     :param object_description: The object description of the file.
#      68     """
# ---> 69     description_string = object_description.generate_description_from_file(path, name, extension)
#      70     self.write_to_cache(description_string, cache_path)
#
# File ~/robocup_workspaces/pycram_ws/src/pycram/src/pycram/description.py:625, in ObjectDescription.generate_description_from_file(self, path, name, extension)
#     623     description_string = self.generate_from_mesh_file(path, name)
#     624 elif extension == self.get_file_extension():
# --> 625     description_string = self.generate_from_description_file(path)
#     626 else:
#     627     try:
#     628         # Using the description from the parameter server
#
# File ~/robocup_workspaces/pycram_ws/src/pycram/src/pycram/object_descriptors/urdf.py:225, in ObjectDescription.generate_from_description_file(self, path)
#     223     except rospkg.ResourceNotFound as e:
#     224         rospy.logerr(f"Could not find resource package linked in this URDF")
# --> 225         raise e
#     226 return urdf_string
#
# File ~/robocup_workspaces/pycram_ws/src/pycram/src/pycram/object_descriptors/urdf.py:222, in ObjectDescription.generate_from_description_file(self, path)
#     220 urdf_string = self.fix_link_attributes(urdf_string)
#     221 try:
# --> 222     urdf_string = self.correct_urdf_string(urdf_string)
#     223 except rospkg.ResourceNotFound as e:
#     224     rospy.logerr(f"Could not find resource package linked in this URDF")
#
# File ~/robocup_workspaces/pycram_ws/src/pycram/src/pycram/object_descriptors/urdf.py:290, in ObjectDescription.correct_urdf_string(self, urdf_string)
#     288     s = line.split('//')
#     289     s1 = s[1].split('/')
# --> 290     path = r.get_path(s1[0])
#     291     line = line.replace("package://" + s1[0], path)
#     292 new_urdf_string += line + '\n'
#
# File /usr/local/lib/python3.8/dist-packages/rospkg/rospack.py:207, in ManifestManager.get_path(self, name)
#     205 self._update_location_cache()
#     206 if name not in self._location_cache:
# --> 207     raise ResourceNotFound(name, ros_paths=self._ros_paths)
#     208 else:
#     209     return self._location_cache[name]
#
# ResourceNotFound: stretch_description
# ROS path [0]=/opt/ros/noetic/share/ros
# ROS path [1]=/home/vee/robocup_workspaces/pycram_ws/src/iai_maps/chemistry_laboratory
# ROS path [2]=/home/vee/robocup_workspaces/pycram_ws/src/iai_robots/iai_adapter_iso50_kinect2_description
# ROS path [3]=/home/vee/robocup_workspaces/pycram_ws/src/iai_robots/iai_adapters_description
# ROS path [4]=/home/vee/robocup_workspaces/pycram_ws/src/iai_maps/iai_apartment
# ROS path [5]=/home/vee/robocup_workspaces/pycram_ws/src/iai_robots/iai_boxy_base
# ROS path [6]=/home/vee/robocup_workspaces/pycram_ws/src/iai_robots/iai_boxy_base_2
# ROS path [7]=/home/vee/robocup_workspaces/pycram_ws/src/iai_robots/iai_boxy_description
# ROS path [8]=/home/vee/robocup_workspaces/pycram_ws/src/iai_robots/iai_boxy_torso
# ROS path [9]=/home/vee/robocup_workspaces/pycram_ws/src/iai_robots/iai_donbot_description
# ROS path [10]=/home/vee/robocup_workspaces/pycram_ws/src/iai_robots/iai_kinect2_description
# ROS path [11]=/home/vee/robocup_workspaces/pycram_ws/src/iai_robots/iai_kinect2_look_target
# ROS path [12]=/home/vee/robocup_workspaces/pycram_ws/src/iai_robots/iai_kinect_description
# ROS path [13]=/home/vee/robocup_workspaces/pycram_ws/src/iai_maps/iai_kitchen
# ROS path [14]=/home/vee/robocup_workspaces/pycram_ws/src/iai_maps/iai_kitchen_defs
# ROS path [15]=/home/vee/robocup_workspaces/pycram_ws/src/iai_robots/iai_kms_40_description
# ROS path [16]=/home/vee/robocup_workspaces/pycram_ws/src/iai_robots/iai_kuka_lwr4_description
# ROS path [17]=/home/vee/robocup_workspaces/pycram_ws/src/iai_maps/iai_maps
# ROS path [18]=/home/vee/robocup_workspaces/pycram_ws/src/iai_robots/iai_pepper_demo_ros_bridge
# ROS path [19]=/home/vee/robocup_workspaces/pycram_ws/src/iai_maps/iai_refills_lab
# ROS path [20]=/home/vee/robocup_workspaces/pycram_ws/src/iai_robots/iai_robots
# ROS path [21]=/home/vee/robocup_workspaces/pycram_ws/src/iai_robots/iai_roller_description
# ROS path [22]=/home/vee/robocup_workspaces/pycram_ws/src/iai_robots/iai_schunk_pw070_v6
# ROS path [23]=/home/vee/robocup_workspaces/pycram_ws/src/iai_maps/iai_semantic_maps
# ROS path [24]=/home/vee/robocup_workspaces/pycram_ws/src/iai_maps/iai_shelves
# ROS path [25]=/home/vee/robocup_workspaces/pycram_ws/src/iai_robots/iai_table_robot_description
# ROS path [26]=/home/vee/robocup_workspaces/pycram_ws/src/iai_robots/iai_ur3
# ROS path [27]=/home/vee/robocup_workspaces/pycram_ws/src/iai_robots/iai_ur_description
# ROS path [28]=/home/vee/robocup_workspaces/pycram_ws/src/iai_robots/iai_weiss_wsg50
# ROS path [29]=/home/vee/robocup_workspaces/pycram_ws/src/iai_robots/iai_wsg_50_description
# ROS path [30]=/home/vee/robocup_workspaces/pycram_ws/src/kdl_ik_services
# ROS path [31]=/home/vee/robocup_workspaces/pycram_ws/src/pr2_kinematics/pr2_arm_kinematics
# ROS path [32]=/home/vee/robocup_workspaces/pycram_ws/src/pr2_common/pr2_common
# ROS path [33]=/home/vee/robocup_workspaces/pycram_ws/src/pr2_common/pr2_dashboard_aggregator
# ROS path [34]=/home/vee/robocup_workspaces/pycram_ws/src/pr2_common/pr2_description
# ROS path [35]=/home/vee/robocup_workspaces/pycram_ws/src/pr2_kinematics/pr2_kinematics
# ROS path [36]=/home/vee/robocup_workspaces/pycram_ws/src/pr2_common/pr2_machine
# ROS path [37]=/home/vee/robocup_workspaces/pycram_ws/src/pr2_common/pr2_msgs
# ROS path [38]=/home/vee/robocup_workspaces/pycram_ws/src/pycram
# ROS path [39]=/home/vee/robocup_workspaces/external_ws/src/actionlib/actionlib
# ROS path [40]=/home/vee/robocup_workspaces/external_ws/src/actionlib/actionlib_tools
# ROS path [41]=/home/vee/robocup_workspaces/external_ws/src/giskard_msgs
# ROS path [42]=/home/vee/robocup_workspaces/external_ws/src/giskardpy
# ROS path [43]=/home/vee/robocup_workspaces/external_ws/src/robokudo/robokudo_msgs
# ROS path [44]=/home/vee/robocup_workspaces/external_ws/src/robokudo/robokudo
# ROS path [45]=/home/vee/robocup_workspaces/external_ws/src/suturo_perception2324/milestone0
# ROS path [46]=/home/vee/robocup_workspaces/external_ws/src/suturo_perception2324/milestone1
# ROS path [47]=/home/vee/robocup_workspaces/external_ws/src/robokudo_human_detection
# ROS path [48]=/home/vee/robocup_workspaces/external_ws/src/robokudo_yolo
# ROS path [49]=/home/vee/robocup_workspaces/deps_ws/src/iai_hsr/hsr_description
# ROS path [50]=/home/vee/robocup_workspaces/deps_ws/src/iai_hsr/hsr_meshes
# ROS path [51]=/home/vee/robocup_workspaces/deps_ws/src/iai_hsr/hsr_navigation
# ROS path [52]=/home/vee/robocup_workspaces/deps_ws/src/iai_hsr/hsr_velocity_controller
# ROS path [53]=/home/vee/robocup_workspaces/deps_ws/src/iai_hsr/iai_hsr_bringup
# ROS path [54]=/home/vee/robocup_workspaces/deps_ws/src/suturo_resources/messages/manipulation_msgs
# ROS path [55]=/home/vee/robocup_workspaces/deps_ws/src/suturo_resources/messages/navigation_msgs
# ROS path [56]=/home/vee/robocup_workspaces/deps_ws/src/suturo_resources/messages/nlg_msgs
# ROS path [57]=/home/vee/robocup_workspaces/deps_ws/src/suturo_resources/messages/nlp_msgs
# ROS path [58]=/home/vee/robocup_workspaces/deps_ws/src/suturo_resources/messages/std_srvs
# ROS path [59]=/home/vee/robocup_workspaces/deps_ws/src/suturo_resources/suturo_gz_text_renderer
# ROS path [60]=/home/vee/robocup_workspaces/deps_ws/src/suturo_resources/messages/suturo_perception_msgs
# ROS path [61]=/home/vee/robocup_workspaces/deps_ws/src/suturo_resources/messages/knowledge_msgs
# ROS path [62]=/home/vee/robocup_workspaces/deps_ws/src/suturo_resources/suturo_resources
# ROS path [63]=/home/vee/robocup_workspaces/deps_ws/src/suturo_resources/suturo_bringup
# ROS path [64]=/home/vee/robocup_workspaces/deps_ws/src/suturo_resources/suturo_room_viz
# ROS path [65]=/opt/ros/noetic/share
